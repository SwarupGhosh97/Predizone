# %%
from tkinter import *
from tkinter import ttk
from tkinter.ttk import Combobox
from PIL import ImageTk, Image
import tkinter as tk
from time import sleep
import pandas as pd
from Regression import LogisticRegression as lr

# %% [markdown]
# # Diabetes dataset

# %%
diabetes = pd.read_csv("C:/Users/USER/Desktop/ML Project/dataset/diabetes.csv")

# %%
x1 = diabetes[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]
y1 = diabetes['Outcome']

# %% [markdown]
# # Help

# %%
def Help():
    root = tk.Tk()
    root.title("Help")
    root.geometry("650x450")
    root.configure(bg='white')

        #logo
    logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
    logolbl = Label(root,image= logo,text="",bg='white')
    logolbl.place(x=20,y=15)
    
        #Home FAQ ContactUs Help
    def ret():
        root.destroy()
        home()
    hom = Button(root,text="Home",bg='white',relief=FLAT,command=ret,cursor='hand2')#,command=Homepage)
    hom.config(font=("Consolas Bold",12))
    hom.place(x=350,y=27)
    def ret1():
        root.destroy()
        Faq()
    faq = Button(root,text="FAQ",bg='white',relief=FLAT,cursor='hand2',command=ret1)
    faq.config(font=("Consolas Bold",12))
    faq.place(x=525,y=27)
    def ret2():
        root.destroy()
        contactus()
    con = Button(root,text="Contact Us",bg='white',relief=FLAT,command=ret2,cursor='hand2')
    con.config(font=("Consolas Bold",12))
    con.place(x=410,y=27)

    hel = Button(root,text="Help",bg='white',relief=FLAT) #command=search
    hel.config(font=("Consolas Bold",12))
    hel.place(x=580,y=27)
    
   
    con = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/help.png")
    conlbl = Label(root,image= con,text="",bg='white')
    conlbl.place(x=-2,y=90)
    

    foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
    footlb = Label(root,image= foot,text="",bg='white')
    footlb.place(x=-2,y=330)


    root.mainloop()

# %% [markdown]
# # FAQ

# %%
def Faq():
    root = tk.Tk()
    root.title("FAQ's")
    root.geometry("650x450")
    root.configure(bg='white')

        #logo
    logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
    logolbl = Label(root,image= logo,text="",bg='white')
    logolbl.place(x=20,y=15)
    
        #Home FAQ ContactUs Help
    def ret():
        root.destroy()
        home()
    hom = Button(root,text="Home",bg='white',relief=FLAT,command=ret,cursor='hand2')#,command=Homepage)
    hom.config(font=("Consolas Bold",12))
    hom.place(x=350,y=27)

    faq = Button(root,text="FAQ",bg='white',relief=FLAT)
    faq.config(font=("Consolas Bold",12))
    faq.place(x=525,y=27)
    def ret2():
        root.destroy()
        contactus()
    con = Button(root,text="Contact Us",bg='white',relief=FLAT,cursor='hand2',command=ret2)
    con.config(font=("Consolas Bold",12))
    con.place(x=410,y=27)
    def ret1():
        root.destroy()
        Help()
    hel = Button(root,text="Help",bg='white',relief=FLAT,command=ret1,cursor='hand2') #command=search
    hel.config(font=("Consolas Bold",12))
    hel.place(x=580,y=27)
    
   
    con = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/faq.png")
    conlbl = Label(root,image= con,text="",bg='white')
    conlbl.place(x=-2,y=90)
    

    foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
    footlb = Label(root,image= foot,text="",bg='white')
    footlb.place(x=-2,y=330)


    root.mainloop()

# %% [markdown]
# # Contact Us

# %%
def contactus():
    root = tk.Tk()
    root.title("Contact Us")
    root.geometry("650x450")
    root.configure(bg='white')

        #logo
    logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
    logolbl = Label(root,image= logo,text="",bg='white')
    logolbl.place(x=20,y=15)
    
        #Home FAQ ContactUs Help
    def ret():
        root.destroy()
        home()
    hom = Button(root,text="Home",bg='white',relief=FLAT,command=ret,cursor='hand2')#,command=Homepage)
    hom.config(font=("Consolas Bold",12))
    hom.place(x=350,y=27)
    def ret1():
        root.destroy()
        Faq()
    faq = Button(root,text="FAQ",bg='white',relief=FLAT,command=ret1,cursor='hand2')
    faq.config(font=("Consolas Bold",12))
    faq.place(x=525,y=27)

    con = Button(root,text="Contact Us",bg='white',relief=FLAT)
    con.config(font=("Consolas Bold",12))
    con.place(x=410,y=27)
    def ret2():
        root.destroy()
        Help()
    hel = Button(root,text="Help",bg='white',relief=FLAT,cursor='hand2',command=ret2) #command=search
    hel.config(font=("Consolas Bold",12))
    hel.place(x=580,y=27)
    
   
    con = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/contactus.png")
    conlbl = Label(root,image= con,text="",bg='white')
    conlbl.place(x=-2,y=90)
    

    foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
    footlb = Label(root,image= foot,text="",bg='white')
    footlb.place(x=-2,y=330)


    root.mainloop()

# %% [markdown]
# # Home Page

# %%
 def home():
    #welcome()
    #Home page
    window = Tk()
    window.title("Predizione")
    window.geometry("650x450")
    window.configure(bg='white')

    #logo
    logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
    logolbl = Label(window,image= logo,text="",bg='white')
    logolbl.place(x=20,y=15)

    #Home FAQ ContactUs Help
    hom = Button(window,text="Home",bg='white',relief=FLAT) #command=search
    hom.config(font=("Consolas Bold",12))
    hom.place(x=350,y=27)
    
    def fun2():
        window.destroy()
        Faq()
    faq = Button(window,text="FAQ",bg='white',relief=FLAT,cursor='hand2',command=fun2) #command=search
    faq.config(font=("Consolas Bold",12))
    faq.place(x=525,y=27)
    
    def fun1():
        window.destroy()
        contactus()
    con = Button(window,text="Contact Us",bg='white',relief=FLAT,command=fun1,cursor='hand2') #command=search
    con.config(font=("Consolas Bold",12))
    con.place(x=410,y=27)
    def fun3():
        window.destroy()
        Help()
    hel = Button(window,text="Help",bg='white',relief=FLAT,cursor='hand2',command=fun3) #command=search
    hel.config(font=("Consolas Bold",12))
    hel.place(x=580,y=27)

    def fun4():
        window.destroy()
        Weather1()
    #weather button
    weather = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/weather2.png")
    weatherlb = Label(window,image= weather,text="",bg='white')
    weatherlb.place(x = 40, y = 115)
    weatherbtn = Button(window,text="Weather",bg='white',relief=FLAT,cursor='hand2',command=fun4) #command=search
    weatherbtn.config(font=("Consolas Bold",12))
    weatherbtn.place(x=81,y=272)
    
    def fun5():
        window.destroy()
        Stock()
    #sales
    sales = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/sales.png")
    saleslb = Label(window,image= sales,text="",bg='white')
    saleslb.place(x = 240, y = 115)
    salesbtn = Button(window,text="Stock Market",bg='white',relief=FLAT,cursor='hand2',command=fun5) #command=search
    salesbtn.config(font=("Consolas Bold",12))
    salesbtn.place(x=259,y=272)
    
    def fun():
        window.destroy()
        Health()
        
    #Health
    health = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/health2.png")
    healthlb = Label(window,image= health,text="",bg='white')
    healthlb.place(x = 450, y = 115)
    healthbtn = Button(window,text="Health Care",bg='white',relief=FLAT,cursor="hand2",command=fun) 
    healthbtn.config(font=("Consolas Bold",12))
    healthbtn.place(x=472,y=272)

    #footer
    foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
    footlb = Label(window,image= foot,text="",bg='white')
    footlb.place(x=-2,y=330)

    window.mainloop()

# %% [markdown]
# # Welcome Page

# %%
def welcome():
    #loading page
    def task():
        # The window will stay open until this function call ends.
        sleep(2) # Replace this with the code you want to run
        root.destroy()

    root = tk.Tk()
    root.title("Welcome")
    root.geometry("650x450")
    root.configure(bg='white')
    load = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/loading.png")
    loadlbl = tk.Label(root,image= load,text="",bg='white')
    loadlbl.place(x=-2,y=0)

    root.after(400, task)
    root.mainloop()
    home()

# %% [markdown]
# # Health Care

# %%
def Health():
    root = tk.Tk()
    root.title("Predizione ( Health Care ) ")
    root.geometry("650x450")
    root.configure(bg='white')

        #logo
    logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
    logolbl = Label(root,image= logo,text="",bg='white')
    logolbl.place(x=20,y=15)
    def ret():
        root.destroy()
        home()
        #Home FAQ ContactUs Help
    hom = Button(root,text="Home",bg='white',relief=FLAT,command=ret,cursor='hand2') #command=Homepage
    hom.config(font=("Consolas Bold",12))
    hom.place(x=350,y=27)
    def fun2():
        root.destroy()
        Faq()
    faq = Button(root,text="FAQ",bg='white',relief=FLAT,command=fun2,cursor='hand2')
    faq.config(font=("Consolas Bold",12))
    faq.place(x=525,y=27)
    def fun3():
        root.destroy()
        contactus()
    con = Button(root,text="Contact Us",bg='white',relief=FLAT,command=fun3,cursor='hand2')
    con.config(font=("Consolas Bold",12))
    con.place(x=410,y=27)
    def fun4():
        root.destroy()
        Help()
    hel = Button(root,text="Help",bg='white',relief=FLAT,command=fun4,cursor='hand2') #command=search
    hel.config(font=("Consolas Bold",12))
    hel.place(x=580,y=27)
    
    #filtering
    lb1 = Label(root,text="Select disease",bg="white")
    lb1.config(font=("Consolas Bold",14))
    lb1.place(x=20,y=110)  
    #female diab menu
    def Fdiab():
        #submit button
        def submit(data):
            a,b,c,d,e,f,g,h=eval(data[0]),eval(data[1]),eval(data[2]),eval(data[3]),eval(data[4]),eval(data[5]),eval(data[6]),eval(data[7])
            pred = lr.prediction(x1,y1,diabetes,[a,b,c,d,e,f,g,h])
            return pred
        def check():
            if submit([text1.get(),text2.get(),text3.get(),text4.get(),text5.get(),text6.get(),text7.get(),text8.get()]) > .5:
                root = Toplevel()
                root.title("Predizione ( Health Care ) ")
                root.geometry("650x450")
                root.configure(bg='white')
                #logo
                logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
                logolbl = Label(root,image= logo,text="",bg='white')
                logolbl.place(x=20,y=15)
                def fun3():
                    root.destroy()
                back = Button(root,text="<<<",bg='White',relief=FLAT,command=fun3,cursor='hand2')
                back.config(font=("Consolas Bold",18))
                back.place(x=410,y=24)
                
                lb1 = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/havediabetes.png")
                lb2 = Label(root,image= lb1,text="",bg='white')
                lb2.place(x=-2,y=90)
                #footer
                foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
                footlb = Label(root,image= foot,text="",bg='white')
                footlb.place(x=-2,y=330)
                root.mainloop()
            else:
                root = Toplevel()
                root.title("Predizione ( Health Care ) ")
                root.geometry("650x450")
                root.configure(bg='white')
                #logo
                logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
                logolbl = Label(root,image= logo,text="",bg='white')
                logolbl.place(x=20,y=15)
                def fun3():
                    root.destroy()
                back = Button(root,text="<<<",bg='white',relief=FLAT,command=fun3,cursor='hand2')
                back.config(font=("Consolas Bold",18))
                back.place(x=410,y=24)
                
                lb1 = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/nodiabetes.png")
                lb2 = Label(root,image= lb1,text="",bg='white')
                lb2.place(x=-2,y=90)
                #footer
                foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
                footlb = Label(root,image= foot,text="",bg='white')
                footlb.place(x=-2,y=330)
                root.mainloop()
        #1
        lb1 = Label(root,text="Pregnancies    :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=20,y=190)
        text1 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text1.place(x=185,y=193)
        #2
        lb1 = Label(root,text="Glucose        :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=20,y=220)
        text2 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text2.place(x=185,y=223)
        #3
        lb1 = Label(root,text="Blood Pressure :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=20,y=250)
        text3 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text3.place(x=185,y=253)
        #4
        lb1 = Label(root,text="Skin Thickness :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=20,y=280)
        text4 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text4.place(x=185,y=283)
        #5
        lb1 = Label(root,text="Insulin           :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=310,y=190)
        text5 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text5.place(x=505,y=193)
        #6
        lb1 = Label(root,text="BMI               :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=310,y=220)
        text6 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text6.place(x=505,y=223)
        #7
        lb1 = Label(root,text="Pedigree Function :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=310,y=250)
        text7 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text7.place(x=505,y=253)
        #8
        lb1 = Label(root,text="Age               :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=310,y=280)
        text8 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text8.place(x=505,y=283)
        #check button
        chkbtn = Button(root,text="Check Result",relief=FLAT,bg='orange',width=14,command=check,cursor='hand2')
        chkbtn.config(font=("Consolas Bold",10))
        chkbtn.place(x=485,y=120)
        
    #male diab menu
    def Mdiab():
        #submit button
        def submit(data):
            a = 0
            b,c,d,e,f,g,h=eval(data[1]),eval(data[2]),eval(data[3]),eval(data[4]),eval(data[5]),eval(data[6]),eval(data[7])
            pred = lr.prediction(x1,y1,diabetes,[a,b,c,d,e,f,g,h])
            return pred
        def check():
            if submit([text1.get(),text2.get(),text3.get(),text4.get(),text5.get(),text6.get(),text7.get(),text8.get()]) > .5:
                root = Toplevel()
                root.title("Predizione ( Health Care ) ")
                root.geometry("650x450")
                root.configure(bg='white')
                #logo
                logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
                logolbl = Label(root,image= logo,text="",bg='white')
                logolbl.place(x=20,y=15)
                def fun3():
                    root.destroy()
                back = Button(root,text="<<<",bg='white',relief=FLAT,command=fun3,cursor='hand2')
                back.config(font=("Consolas Bold",18))
                back.place(x=410,y=24)
                
                lb1 = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/havediabetes.png")
                lb2 = Label(root,image= lb1,text="",bg='white')
                lb2.place(x=-2,y=90)
                #footer
                foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
                footlb = Label(root,image= foot,text="",bg='white')
                footlb.place(x=-2,y=330)
                root.mainloop()
            else:
                root = Toplevel()
                root.title("Predizione ( Health Care ) ")
                root.geometry("650x450")
                root.configure(bg='white')
                #logo
                logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
                logolbl = Label(root,image= logo,text="",bg='white')
                logolbl.place(x=20,y=15)
                
                def fun3():
                    root.destroy()
                back = Button(root,text="<<<",bg='white',relief=FLAT,command=fun3,cursor='hand2')
                back.config(font=("Consolas Bold",18))
                back.place(x=410,y=24)
                
                
                lb1 = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/nodiabetes.png")
                lb2 = Label(root,image= lb1,text="",bg='white')
                lb2.place(x=-2,y=90)
                #footer
                foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
                footlb = Label(root,image= foot,text="",bg='white')
                footlb.place(x=-2,y=330)
                root.mainloop()
        #1
        lb1 = Label(root,text="Pregnancies    :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=20,y=190)
        text1 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text1.config(state=DISABLED)
        text1.place(x=185,y=193)
        #2
        lb1 = Label(root,text="Glucose        :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=20,y=220)
        text2 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text2.place(x=185,y=223)
        #3
        lb1 = Label(root,text="Blood Pressure :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=20,y=250)
        text3 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text3.place(x=185,y=253)
        #4
        lb1 = Label(root,text="Skin Thickness :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=20,y=280)
        text4 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text4.place(x=185,y=283)
        #5
        lb1 = Label(root,text="Insulin           :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=310,y=190)
        text5 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text5.place(x=505,y=193)
        #6
        lb1 = Label(root,text="BMI               :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=310,y=220)
        text6 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text6.place(x=505,y=223)
        #7
        lb1 = Label(root,text="Pedigree Function :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=310,y=250)
        text7 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text7.place(x=505,y=253)
        #8
        lb1 = Label(root,text="Age               :",bg="white")
        lb1.config(font=("Consolas Bold",12))
        lb1.place(x=310,y=280)
        text8 = tk.Entry(root,width=10,relief='solid',borderwidth=1,bg='snow')
        text8.place(x=505,y=283)
        #check button
        chkbtn = Button(root,text="Check Result",relief=FLAT,bg='orange',width=14,command=check,cursor='hand2')
        chkbtn.config(font=("Consolas Bold",10))
        chkbtn.place(x=485,y=120)
        
    #choose gender
    def gen():
        lb2 = Label(root,text="Select Gender",bg="white")
        lb2.config(font=("Consolas Bold",14))
        lb2.place(x=20,y=140)
        choice=Combobox(root)
        choice['values']=("-----Select-----","Male","Female")
        choice.place(x=185,y=140)
        choice.current(0)
        def cho():
            if choice.get()=="Male":
                Mdiab()
            elif choice.get()=="Female":
                Fdiab()
        Button(root,text="Next",command=cho,relief=FLAT,bg='orange',width=10,cursor='hand2').place(x=350,y=140)
        
    #diab()
    choice=Combobox(root)
    choice['values']=("-----Select-----","Diabetes")
    choice.place(x=185,y=110)
    choice.current(0)
    def cho():
        if choice.get()=="Diabetes":
            gen()
    Button(root,text="Next",command=cho,relief=FLAT,bg='orange',width=10,cursor='hand2').place(x=350,y=110)
    
    #footer
    foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
    footlb = Label(root,image= foot,text="",bg='white')
    footlb.place(x=-2,y=330)

    root.mainloop()

# %% [markdown]
# # Weather

# %%
def Weather1():
                window = tk.Tk()
                window.title("Predizione ( Weather )")
                window.geometry("650x450")
                window.configure(bg='white')


                logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
                logolbl = Label(window,image= logo,text="",bg='white')
                logolbl.place(x=20,y=15)
    
                    #Home FAQ ContactUs Help
                def ret1():
                    window.destroy()
                    home()
                hom = Button(window,text="Home",bg='white',relief=FLAT,command=ret1,cursor='hand2')
                hom.config(font=("Consolas Bold",12))
                hom.place(x=350,y=27)
                def ret2():
                    window.destroy()
                    Faq()
                faq = Button(window,text="FAQ",bg='white',relief=FLAT,command=ret2,cursor='hand2')
                faq.config(font=("Consolas Bold",12))
                faq.place(x=525,y=27)
                def ret3():
                    window.destroy()
                    contactus()
                con = Button(window,text="Contact Us",bg='white',relief=FLAT,command=ret3,cursor='hand2')
                con.config(font=("Consolas Bold",12))
                con.place(x=410,y=27)
                def ret4():
                    window.destroy()
                    Help()
                hel = Button(window,text="Help",bg='white',relief=FLAT,command=ret4,cursor='hand2') #command=search
                hel.config(font=("Consolas Bold",12))
                hel.place(x=580,y=27)



                lbl1 = Label(window,text="Enter Apparent Temperature(in Centigrade) : ",bg= "white")
                lbl1.place(x=20,y=110)

                Atemp = tk.Entry(window,relief='solid',borderwidth=1,bg="snow")
                Atemp.place(x=270,y=110)

                lbl1 = Label(window,text="Enter Humidity : ",bg= "white")
                lbl1.place(x=20,y=170)

                Hum = tk.Entry(window,relief='solid',borderwidth=1,bg="snow")
                Hum.place(x=170,y=170)

                lbl1 = Label(window,text="Enter Wind Speed(km/h) : ",bg= "white")
                lbl1.place(x=320,y=170)

                wind = tk.Entry(window,relief='solid',borderwidth=1,bg="snow")
                wind.place(x=490,y=170)


                lbl1 = Label(window,text="Enter Visibility(km) : ",bg= "white")
                lbl1.place(x=20,y=230)

                vis = tk.Entry(window,relief='solid',borderwidth=1,bg="snow")
                vis.place(x=170,y=230)

                lbl1 = Label(window,text="Enter Wind Bearing(degrees) : ",bg= "white")
                lbl1.place(x=320,y=230)

                wb = tk.Entry(window,relief='solid',borderwidth=1,bg="snow")
                wb.place(x=490,y=230)

                lbl1 = Label(window,text="Enter Pressure(millibars) : ",bg= "white")
                lbl1.place(x=20,y=290)

                pres = tk.Entry(window,relief='solid',borderwidth=1,bg="snow")
                pres.place(x=170,y=290)
                def check1():
                    if(combo.get()=="rain"):
                        check2([1,Atemp.get(),Hum.get(),wind.get(),wb.get(),vis.get(),pres.get()])
                    elif(combo.get()=="snow"):
                        check2([2,Atemp.get(),Hum.get(),wind.get(),wb.get(),vis.get(),pres.get()])
                    else:
                        check2([0,Atemp.get(),Hum.get(),wind.get(),wb.get(),vis.get(),pres.get()])

                btn = Button(window, text="Check Weather",command=check1,relief=FLAT,cursor='hand2',bg='orange',width=15)
                btn.place(x=450,y=100)

                lbl1 = Label(window,text="Enter Precipitaion Type : ",bg= "white")
                lbl1.place(x=320,y=290)

                combo = Combobox(window)
                combo['values']=("------Select------","rain","snow","sunny")
                combo.current(0) #set the selected item
                combo.place(x=490,y=290)

                foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
                footlb = Label(window,image= foot,text="",bg='white')
                footlb.place(x=-2,y=330)


                window.mainloop()

def check2(data):
                #import Swarup_Linear_Reg as swl #Own Module
                import pandas as pd
                import statistics as st
                from sklearn import tree
                from sklearn.tree import DecisionTreeClassifier
                from sklearn.linear_model import LinearRegression
                window = Toplevel()
                window.title("Predizione")
                window.geometry("650x450")
                window.configure(bg='white')


                logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
                logolbl = Label(window,image= logo,text="",bg='white')
                logolbl.place(x=20,y=15)

                def fun3():
                    window.destroy()
                back = Button(window,text="<<<",bg='white',relief=FLAT,command=fun3,cursor='hand2')
                back.config(font=("Consolas Bold",18))
                back.place(x=410,y=20)

                foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
                footlb = Label(window,image=foot,text="",bg='white')
                footlb.place(x=-2,y=330)

                def get_data(file_name):
                    data = pd.read_csv(file_name)
                    x_parameter = []
                    y_parameter = []
                    #x = USA_Housing[['Avg._Area_Income', 'Avg._Area_House_Age', 'Avg._Area_Number_of_Rooms', 'Avg._Area_Number_of_Bedrooms', 'Area_Population']]
                        #x_parameter.append(float(x1))
                    #x=[[data['Apparent Temperature (C)']],[data['Humidity']],[data['Wind Speed (km/h)']],[data['Wind Bearing (degrees)']],[data['Visibility (km)']],[data['Pressure (millibars)']]]
                    y = data['Temperature (C)']
                    x1=data.drop(columns=["Summary","Loud Cover","Formatted Date","Daily Summary","Temperature (C)"])
                    y1=data['Summary'].values
                    x=data.drop(columns=["Summary","Loud Cover","Formatted Date","Daily Summary","Temperature (C)","Percip"])
                    #x_parameter=(x.values.tolist())
                    x_parameter=(x)
                    y_parameter=(y)
                    X_parameter=(x1)
                    Y_parameter=(y1)
                    return x_parameter,y_parameter,X_parameter,Y_parameter
                link="C:/Users/USER/Desktop/ML Project/dataset/weatherHistory.csv"
                x,y,x1,y1=get_data(link)
                clf = DecisionTreeClassifier()
                clf = clf.fit(x1,y1)
                pred=[]
                pred.append(data[0])
                pred.append(eval(data[1]))
                pred.append(eval(data[2]))
                pred.append(eval(data[3]))
                pred.append(eval(data[4]))
                pred.append(eval(data[5]))
                pred.append(eval(data[6]))
                predict1=[pred]
                predict2=[pred[1:]]
                #p3=swl.predict(x,y,pred[1:]) 
                lm = LinearRegression()
                lm.fit(x,y)
                p3=lm.predict(predict2)
                p4=clf.predict(predict1)


                if(p4[0]=="Mostly Cloudy" or p4[0]=="Humid and Mostly Cloudy" or p4[0]=="Dry and Mostly Cloudy" or p4[0]=="Dry and Partly Cloudy" or p4[0]=="Humid and Partly Cloudy" or p4[0]=="Partly Cloudy"  or p4[0]=="Windy and Partly Cloudy" ):
                    cloud = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/images.png")
                    cloudy = Label(window,image=cloud,text="",bg='white')
                    cloudy.place(x=150,y=90)
                    lbl1 = Label(window,text=round(p3[0],1),bg= "white",font=("Consolas Bold",32)) 
                    lbl1.place(x=317,y=105)
                    centi = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/download (1).png")
                    c = Label(window,image=centi,text="",bg='white')
                    c.place(x=432,y=95)
                    lbl2 = Label(window,text=p4[0],bg= "white",font=("Consolas Bold",12))
                    lbl2.place(x=322,y=150)

                elif(p4[0]=="Breezy" or p4[0]=="Breezy and Dry" or p4[0]=="Breezy and Foggy" or p4[0]=="Breezy and Overcast" or p4[0]=="Windy and Mostly Cloudy" or p4[0]=="Foggy" or p4[0]=="Windy and Foggy" or p4[0]=="Windy and Dry"):
                    wind = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/download.png")
                    windy = Label(window,image=wind,text="",bg='white')
                    windy.place(x=128,y=75)
                    lbl1 = Label(window,text=round(p3[0],1),bg= "white",font=("Consolas Bold",32)) 
                    lbl1.place(x=317,y=105)
                    centi = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/download (1).png")
                    c = Label(window,image=centi,text="",bg='white')
                    c.place(x=432,y=95)
                    lbl2 = Label(window,text=p4[0],bg= "white",font=("Consolas Bold",12))
                    lbl2.place(x=322,y=150)


                elif(p4[0]=="Dangerously Windy and Partly Cloudy" or p4[0]=="Drizzle" or p4[0]=="Light 1" ):
                    wind2 = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/Thunderstorms.png")
                    windy2 = Label(window,image=wind2,text="",bg='white')
                    windy2.place(x=128,y=90)
                    lbl1 = Label(window,text=round(p3[0],1),bg= "white",font=("Consolas Bold",32)) 
                    lbl1.place(x=317,y=105)
                    centi = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/download (1).png")
                    c = Label(window,image=centi,text="",bg='white')
                    c.place(x=432,y=95)
                    lbl2 = Label(window,text=p4[0],bg= "white",font=("Consolas Bold",12))
                    lbl2.place(x=324,y=150)

                else :
                    sun = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/6f4adf551b05fda7db635aecddd560a0.png")
                    sunny = Label(window,image=sun,text="",bg='white')
                    sunny.place(x=116,y=75)
                    lbl1 = Label(window,text=round(p3[0],1),bg= "white",font=("Consolas Bold",32)) 
                    lbl1.place(x=317,y=105)
                    centi = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/download (1).png")
                    c = Label(window,image=centi,text="",bg='white')
                    c.place(x=432,y=95)
                    lbl2 = Label(window,text=p4[0],bg= "white",font=("Consolas Bold",12))
                    lbl2.place(x=322,y=150)


                h = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/download (2).png")
                h1 = Label(window,image=h,text="",bg='white')
                h1.place(x=10,y=273)
                lbl3 = Label(window,text=data[2],bg= "white",font=("Consolas Bold",18))
                lbl3.place(x=54,y=280)
                lbl3 = Label(window,text="Humidity",bg= "white",font=("Consolas Bold",8))
                lbl3.place(x=6,y=312)

                w = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/images (1).png")
                w1 = Label(window,image=w,text="",bg='white')
                w1.place(x=168,y=270)
                lbl4 = Label(window,text=data[3],bg= "white",font=("Consolas Bold",18))
                lbl4.place(x=223,y=280)
                lbl4 = Label(window,text="Wind Speed(Km/h)",bg= "white",font=("Consolas Bold",8))
                lbl4.place(x=162,y=312)

                v = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/download (3).png")
                v1 = Label(window,image=v,text="",bg='white')
                v1.place(x=348,y=270)
                lbl5 = Label(window,text=data[5],bg= "white",font=("Consolas Bold",18))
                lbl5.place(x=396,y=280)
                lbl5 = Label(window,text="Visibility(Km)",bg= "white",font=("Consolas Bold",8))
                lbl5.place(x=338,y=312)

                p = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/images (2).png")
                p1 = Label(window,image=p,text="",bg='white')
                p1.place(x=518,y=270)
                lbl6 = Label(window,text=data[6],bg= "white",font=("Consolas Bold",18))
                lbl6.place(x=568,y=280)
                lbl6 = Label(window,text="Air Pressure(Millibars)",bg= "white",font=("Consolas Bold",8))
                lbl6.place(x=501,y=312)

                window.mainloop()

# %% [markdown]
# # Stock Market

# %%
def Stock():
    #import library
    import os
    import datetime
    from glob import glob
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    from PIL import Image
    import time
    from statistics import mean
    #from tkinter import *
    from tkinter import ttk
    from tkinter.ttk import Combobox
    from PIL import ImageTk, Image
    import tkinter as tk
    from time import sleep
    from sklearn import datasets, linear_model
    from sklearn.metrics import mean_squared_error, r2_score
    from sklearn.linear_model import LinearRegression
    from sklearn import metrics
    from sklearn.model_selection import train_test_split
    
    #start window
    window = tk.Tk()
    window.title("Predizione ( Stock Prediction )")
    window.geometry("650x450")
    window.configure(bg='white')
    
    def submit():
            a = eval(entry.get())
            pred=lm.predict([[a]])
            return pred

      
    
    def AXIS():
        
        tim = Label(window,text="Enter Open Price of Stock :",bg='white')
        tim.config(font=("Consolas Bold",12))
        tim.place(x=20,y=200)

        entry=tk.Entry(window,relief='solid',borderwidth=1,bg='snow')
        entry.place(x=285,y=200)
        
        
        def submit():
            a = eval(entry.get())
            pred = lm.predict([[a]])
            return pred
        def check():
            root = Toplevel()
            root.title("Predizione ( Stock Prediction ) ")
            root.geometry("650x450")
            root.configure(bg='white')
            def fun3():
                root.destroy()
            back = Button(root,text="<<<",bg='white',relief=FLAT,command=fun3,cursor='hand2')
            back.config(font=("Consolas Bold",18))
            back.place(x=410,y=20)
            res = submit()
            logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/icon.png")
            logolbl = Label(root,image= logo,text="",bg='white')
            logolbl.place(x=20,y=15)
            gr = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/AXISGraph.png")
            grlbl = Label(root,image= gr,text="",bg='white')
            grlbl.place(x=0,y=100)
            finlabel = Label(root,text=round(res[0][0],2),bg="white",fg="green")
            finlabel.config(font=("Consolas Bold",20))
            finlabel.place(x=100,y=10)
            
            yp = Label(root,text="AXIS Bank",bg='white')
            yp.config(font=("Consolas",16))
            yp.place(x=100,y=50)
            
            foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
            footlb = Label(root,image= foot,text="",bg='white')
            footlb.place(x=-2,y=330)
            #thnk = PhotoImage(file="C:/Users/Debajit Sengupta/Desktop/ML Project/thnk.png")
            #th = Label(root,image=thnk,text="",bg='white')
            #th.place(x=20,y=250)
            root.mainloop()
            
        predict = Button(window,text="Predict",width=12,bg="orange",relief=FLAT,command=check,cursor='hand2')
        predict.config(font=("Consolas Bold",12))
        predict.place(x=270,y=280)
        link1="C:/Users/USER/Desktop/ML Project/dataset/"
        data1 = pd.read_csv(link1+'AXIS.csv')
        linkdir1=link1
        axis = pd.read_csv(linkdir1+'AXIS.csv')
        #axis.head(len(axis))
        X = axis[['Open Price']]
        y = axis[['RunAvg']]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)
        lm = LinearRegression()
        lm.fit(X_train, y_train)
        predictions = lm.predict(X_test)
        #plt.figure(figsize=(10,10))
        #plt.scatter( y_test, predictions, edgecolor='black')
       
        
        

    def LIC():
        tim = Label(window,text="Enter Open Price of Stock :",bg='white')
        tim.config(font=("Consolas Bold",12))
        tim.place(x=20,y=200)

        entry=tk.Entry(window,relief='solid',borderwidth=1,bg='snow')
        entry.place(x=285,y=200)
        
        def submit():
            a = eval(entry.get())
            pred = lm.predict([[a]])
            return pred
        def check():
            root = Toplevel()
            root.title("Predizione ( Stock Prediction ) ")
            root.geometry("650x450")
            root.configure(bg='white')
            def fun3():
                root.destroy()
            back = Button(root,text="<<<",bg='white',relief=FLAT,command=fun3,cursor='hand2')
            back.config(font=("Consolas Bold",18))
            back.place(x=410,y=20)
            res = submit()
            finlabel = Label(root,text=round(res[0][0],2),bg="white",fg="green")
            finlabel.config(font=("Consolas Bold",20))
            finlabel.place(x=100,y=10)
            logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/icon.png")
            logolbl = Label(root,image= logo,text="",bg='white')
            logolbl.place(x=20,y=15)
            gr = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/LICGraph.png")
            grlbl = Label(root,image= gr,text="",bg='white')
            grlbl.place(x=0,y=100)
            foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
            footlb = Label(root,image= foot,text="",bg='white')
            footlb.place(x=-2,y=330)
            yp = Label(root,text="LIC India",bg='white')
            yp.config(font=("Consolas",16))
            yp.place(x=100,y=50)
            #thnk = PhotoImage(file="C:/Users/Debajit Sengupta/Desktop/ML Project/thnk.png")
            #th = Label(root,image=thnk,text="",bg='white')
            #th.place(x=20,y=250)

            root.mainloop()
        
        predict = Button(window,text="Predict",width=12,bg="orange",relief=FLAT,command=check,cursor='hand2')
        predict.config(font=("Consolas Bold",12))
        predict.place(x=270,y=280)
        def submit():
            a = eval(entry.get())
            pred=lm.predict([[a]])
            return pred
        link2="C:/Users/USER/Desktop/ML Project/dataset/"
        data2 = pd.read_csv(link2+'LIC.csv')
        linkdir2=link2
        lic = pd.read_csv(linkdir2+'LIC.csv')
        #lic.head(len(lic))
        X = lic[['Open Price']]
        y = lic[['RunAvg']] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)
        lm = LinearRegression()
        lm.fit(X_train, y_train)
        predictions = lm.predict(X_test)
        #plt.figure(figsize=(10,10))
        #plt.scatter( y_test, predictions, edgecolor='black')
        
        

    def SBI():
        tim = Label(window,text="Enter Open Price of Stock :",bg='white')
        tim.config(font=("Consolas Bold",12))
        tim.place(x=20,y=200)

        entry=tk.Entry(window,relief='solid',borderwidth=1,bg='snow')
        entry.place(x=285,y=200)
        
        def submit():
            a = eval(entry.get())
            pred = lm.predict([[a]])
            return pred
        def check():
            root = Toplevel()
            root.title("Predizione ( Stock Prediction ) ")
            root.geometry("650x450")
            root.configure(bg='white')
            def fun3():
                root.destroy()
            back = Button(root,text="<<<",bg='white',relief=FLAT,command=fun3,cursor='hand2')
            back.config(font=("Consolas Bold",18))
            back.place(x=410,y=20)
            res = submit()
            finlabel = Label(root,text=round(res[0][0],2),bg="white",fg="green")
            finlabel.config(font=("Consolas Bold",20))
            finlabel.place(x=100,y=10)
            logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/icon.png")
            logolbl = Label(root,image= logo,text="",bg='white')
            logolbl.place(x=20,y=15)
            gr = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/SBIGraph.png")
            grlbl = Label(root,image= gr,text="",bg='white')
            grlbl.place(x=0,y=100)
            foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
            footlb = Label(root,image= foot,text="",bg='white')
            footlb.place(x=-2,y=330)
            yp = Label(root,text="SBI",bg='white')
            yp.config(font=("Consolas",16))
            yp.place(x=100,y=50)
            #thnk = PhotoImage(file="C:/Users/Debajit Sengupta/Desktop/ML Project/thnk.png")
            #th = Label(root,image=thnk,text="",bg='white')
            #th.place(x=20,y=250)
            root.mainloop()
        
        predict = Button(window,text="Predict",width=12,bg="orange",relief=FLAT,command=check,cursor='hand2')
        predict.config(font=("Consolas Bold",12))
        predict.place(x=270,y=280)
        def submit():
            a = eval(entry.get())
            pred=lm.predict([[a]])
            return pred
        link3="C:/Users/USER/Desktop/ML Project/dataset/"
        data3 = pd.read_csv(link3+'SBI.csv')
        linkdir3=link3
        sbi = pd.read_csv(linkdir3+'SBI.csv')
        #sbi.head(len(sbi))
        X = sbi[['Open Price']]
        y = sbi[['RunAvg']] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)
        lm = LinearRegression()
        lm.fit(X_train, y_train)
        predictions = lm.predict(X_test)
        #plt.figure(figsize=(10,10))
        #plt.scatter( y_test, predictions, edgecolor='black')
        
        

    def TCS():
        tim = Label(window,text="Enter Open Price of Stock :",bg='white')
        tim.config(font=("Consolas Bold",12))
        tim.place(x=20,y=200)

        entry=tk.Entry(window,relief='solid',borderwidth=1,bg='snow')
        entry.place(x=285,y=200)
        def submit():
            a = eval(entry.get())
            pred = lm.predict([[a]])
            return pred
        def check():
            root = Toplevel()
            root.title("Predizione ( Stock Prediction ) ")
            root.geometry("650x450")
            root.configure(bg='white')
            def fun3():
                root.destroy()
            back = Button(root,text="<<<",bg='white',relief=FLAT,command=fun3,cursor='hand2')
            back.config(font=("Consolas Bold",18))
            back.place(x=410,y=20)
            res = submit()
            finlabel = Label(root,text=round(res[0][0],2),bg="white",fg="green")
            finlabel.config(font=("Consolas Bold",20))
            finlabel.place(x=100,y=10)
            logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/icon.png")
            logolbl = Label(root,image= logo,text="",bg='white')
            logolbl.place(x=20,y=15)
            gr = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/TCSGraph.png")
            grlbl = Label(root,image= gr,text="",bg='white')
            grlbl.place(x=0,y=100)
            foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
            footlb = Label(root,image= foot,text="",bg='white')
            footlb.place(x=-2,y=330)
            yp = Label(root,text="TCS ",bg='white')
            yp.config(font=("Consolas ",14))
            yp.place(x=100,y=50)
            #thnk = PhotoImage(file="C:/Users/Debajit Sengupta/Desktop/ML Project/thnk.png")
            #th = Label(root,image=thnk,text="",bg='white')
            #th.place(x=20,y=250)
            root.mainloop()
        
        predict = Button(window,text="Predict",width=12,bg="orange",relief=FLAT,command=check,cursor='hand2')
        predict.config(font=("Consolas Bold",12))
        predict.place(x=270,y=280)
        def submit():
            a = eval(entry.get())
            pred=lm.predict([[a]])
            return pred
        link4="C:/Users/USER/Desktop/ML Project/dataset/"
        data4 = pd.read_csv(link4+'TCS.csv')
        linkdir4=link4
        tcs = pd.read_csv(linkdir4+'TCS.csv')
        #tcs.head(len(tcs))
        X = tcs[['Open Price']]
        y = tcs[['RunAvg']] 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)
        lm = LinearRegression()
        lm.fit(X_train, y_train)
        predictions = lm.predict(X_test)
        #plt.figure(figsize=(10,10))
        #plt.scatter( y_test, predictions, edgecolor='black')
        
        
    
    
        #logo
    logo = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/logo1.png")
    logolbl = Label(window,image= logo,text="",bg='white')
    logolbl.place(x=20,y=15)

    #Home FAQ ContactUs Help
    def ret1():
        window.destroy()
        home()
    hom = Button(window,text="Home",bg='white',relief=FLAT,command=ret1,cursor='hand2')#,command=Homepage)
    hom.config(font=("Consolas Bold",12))
    hom.place(x=350,y=27)
    def ret2():
        window.destroy()
        Faq()
    faq = Button(window,text="FAQ",bg='white',relief=FLAT,command=ret2,cursor='hand2')#,command=FAQ)
    faq.config(font=("Consolas Bold",12))
    faq.place(x=525,y=27)
    def ret3():
        window.destroy()
        contactus()
    con = Button(window,text="Contact Us",bg='white',relief=FLAT,command=ret3,cursor='hand2')#,command=contactUs)
    con.config(font=("Consolas Bold",12))
    con.place(x=410,y=27)
    def ret4():
        window.destroy()
        Help()
    hel = Button(window,text="Help",bg='white',relief=FLAT,command=ret4,cursor='hand2') #command=search
    hel.config(font=("Consolas Bold",12))
    hel.place(x=580,y=27)


    #Stock page matetials
    #load = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/Stock.png")
    #label2=tk.Label(window,image=load,text="",bg="white")
    #label2.place(x=0,y=150)
   
    
    comp = Label(window,text="Select Company :",bg='white')
    comp.config(font=("Consolas Bold",16))
    comp.place(x=20,y=130)

    compCombo = ttk.Combobox(window,width=25, 
                                values=[
                                        "-----Select-----",
                                        "AXIS", 
                                        "LIC",
                                        "SBI",
                                        "TCS",])
    compCombo.place(x=230, y=135)
    compCombo.current(0)
    
    def cho():
        if compCombo.get()=="AXIS":
            AXIS()
        elif compCombo.get()=="SBI":
            SBI()
        elif compCombo.get()=="LIC":
            LIC()
        elif compCombo.get()=="TCS":
            TCS()
        


    nextbtn = Button(window,text="Next",bg="orange",width=10,relief=FLAT,command=cho,cursor='hand2')
    #nextbtn.config(font=("Consolas Bold",12))
    nextbtn.place(x=430,y=133)



    #footer
    foot = PhotoImage(file="C:/Users/USER/Desktop/ML Project/Photos/footer2.png")
    footlb = Label(window,image= foot,text="",bg='white')
    footlb.place(x=-2,y=330)

    window.mainloop()

# %%
welcome()
